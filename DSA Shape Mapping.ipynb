# %%
import csv

# %% [raw]
# Read in the County CSV

# %%
filename = "ORG_OPO_Service_OCL_OTH.csv"
reader = csv.DictReader(open(filename, 'rU'))
dsa_dict = {}
 
state_id_dict = {"Alabama" : "01", "Alaska" : "02", "Arizona" : "04", "Arkansas" : "05", "California" : "06", 
                 "Colorado" : "08", "Connecticut" : "09", "District of Columbia" : "11", "Delaware" : "10", 
                 "Florida" : "12", "Georgia" : "13", "Hawaii" : "15", "Idaho" : "16", "Illinois" : "17", 
                 "Indiana" : "18", "Iowa" : "19", "Kansas" : "20", "Kentucky" : "21", "Louisiana" : "22", 
                 "Maine" : "23", "Maryland" : "24", "Massachusetts" : "25", "Michigan" : "26", "Minnesota" : "27", 
                 "Mississippi" : "28", "Missouri" : "29", "Montana" : "30", "Nebraska" : "31", "Nevada" : "32", 
                 "New Hampshire" : "33", "New Jersey" : "34", "New Mexico" : "35", "New York" : "36", 
                 "North Carolina" : "37", "North Dakota" : "38", "Ohio" : "39", "Oklahoma" : "40", "Oregon" : "41", 
                 "Pennsylvania" : "42", "Rhode Island" : "44", "South Carolina" : "45", "South Dakota" : "46", 
                 "Tennessee" : "47", "Texas" : "48", "Utah" : "49", "Vermont" : "50", "Virginia" : "51", 
                 "Washington" : "53", "West Virginia" : "54", "Wisconsin" : "55", "Wyoming" : "56",
                 "Puerto Rico": "72", 'U.S. Virgin Islands': '78'}

#Grab State column, DSA codes and list of counties
total_counties = 0
for row in reader:
    if row["OPOProviderName"] in dsa_dict:
        dsa_name = row["OPOProviderName"]
        state_names = dsa_dict[dsa_name]["state"]
        state_ids = dsa_dict[dsa_name]["state_id"]
        state_names.append(row["StateName"])
        state_ids.append(state_id_dict[row["StateName"]])
        
        dsa_dict[dsa_name]["state_id"] = state_ids#state_id_dict[row["StateName"]])
        dsa_dict[dsa_name]["state"] = state_names

    else:
        #Break list of counties into list
        county_list = row["ServiceCounties"].split(', ')
    
        #print county_list
        dsa_dict[row["OPOProviderName"]] = {'counties': county_list, 'state': [row["StateName"]], 
                                        'state_id': [state_id_dict[row["StateName"]]]}

#print dsa_dict
for item in dsa_dict:
    if "Georgia" in dsa_dict[item]["state"] or "Georgia" in item:
        pass
    for county in dsa_dict[item]["counties"]:
        total_counties = total_counties + 1
        
print len(dsa_dict)
# Out:
# 58

# %% [raw]
# Load list of county names, states and FIPS codes

# %%
import fiona
def get_county_from_fiona(filename):
    
    from shapely.geometry import shape

    data = {}
    county_dupes = {}
    
    c = fiona.open(filename, 'r')
    for shape_data in c:
        #print shape_data['properties']
        fips =  shape_data['properties']['STATEFP'] + shape_data['properties']['COUNTYFP']
        parsed_shape = shape(shape_data['geometry'])
        county_name = shape_data['properties']['NAME']
    
        if county_name in county_dupes:
            fips_list = county_dupes[county_name]
            county_dupes[county_name] = fips_list + [fips]
        else:
            county_dupes[county_name] = [fips] 
    
        #print county_dupes
        data[fips] = parsed_shape

    return (data, county_dupes)

(county_shape_dict, county_dupes) = get_county_from_fiona("cb_2013_us_county_500k/cb_2013_us_county_500k.shp")
#print county_dupes

# %%
from shapely.geometry import shape, Point
def get_centroid_from_fiona(filename, id_param):

    data = {}
    
    c = fiona.open(filename, 'r')
    for shape_data in c:
        parsed_shape = shape(shape_data['geometry'])
        data[shape_data['properties'][id_param]] = parsed_shape.centroid

    return data

state_data = get_centroid_from_fiona("cb_2013_us_state_500k/cb_2013_us_state_500k.shp", "NAME")
state_data["U.S. Virgin Islands"] = Point(-64.8303, 18.0936)

# %% [raw]
#     TODO: translate DSA name into 4 letter code

# %%
#print county_shape_dict["01001"]
singleton_total = 0
for county_name in county_dupes:
    if len(county_dupes[county_name]) == 1:
        singleton_total += 1
        
print singleton_total
print len(county_dupes)
# Out:
# 1476
# 1921

# %%
manual_dict = {'Dona Ana': '35013', 
               'La Porte': '18091', 
               'Lagrange': '18087', 
               'Prince of Wales-Outer Ketchikan': '02198', 
               'Skagway-Hoonah-Angoon': '02230', 
               'Wrangell-Petersburg': '02275', 
               'Alexandria City': '51510', 
               'Fairfax City': '51600', 
               'Falls Church City': '51610', 
               'Fredericksburg City': '51630', 
               'Manassas City': '51683', 
               'Manassas Park City': '51685', 
               'St. Louis City': '29510', 
               'Bedford City': '51515', 
               'Buena Vista City': '51530', 
               'Charlottesville City': '51540', 
               'Chesapeake City': '51550', 
               'Colonial Heights City': '51570', 
               'Covington City': '51580', 
               'Emporia City': '51595', 
               'Franklin City': '51620', 
               'Galax City': '51640', 
               'Hampton City': '51650', 
               'Harrisonburg City': '51660', 
               'Hopewell City': '51670', 
               'Lexington City': '51678', 
               'Lynchburg City': '51680', 
               'Martinsville City': '51690', 
               'Newport News City': '51700', 
               'Norfolk City': '51710', 
               'Petersburg City': '51730', 
               'Poquoson City': '51735', 
               'Portsmouth City': '51740', 
               'Radford City': '51750', 
               'Richmond City': '51760', 
               'Roanoke City': '51770', 
               'Salem City': '51775', 
               'Staunton City': '51790', 
               'Suffolk City': '51800', 
               'Virginia Beach City': '51810', 
               'Waynesboro City': '51820', 
               'Williamsburg City': '51830', 
               'Winchester City': '51840', 
               'Anasco': '72011', 
               "Bayamo'n": '72021', 
               'Canovanas': '72029', 
               'Catano': '72033', 
               'Comerio': '72045', 
               'Guanica': '72055', 
               'Juana Diaz': '72075', 
               'Las Marias': '72083', 
               'Loiza': '72087', 
               'lsabela': '72071', 
               'Manati': '72091', 
               'Mayaguez': '72097', 
               'Penuelas': '72111', 
               'Rincon': '72117', 
               'San German': '72125', 
               'San Sebastian': '72131', 
               'Bristol City': '51520', 
               'Norton City': '51720', 
               'Baltimore City': '24510', 
               'Danville City': '51590'}


county_assignments = {"Adams": {"Pacific Northwest Transplant Bank":"16003",
                                "UW Health Organ and Tissue Donation":"55001",
                                'Gift of Hope Organ & Tissue Donor Network': "17001"},
                      "La Salle": {"Louisiana Organ Procurement Agency": "22059",
                                   "Gift of Hope Organ & Tissue Donor Network": "17099",},
                      "Lincoln": {"UW Health Organ and Tissue Donation": "55069",
                                  "Kentucky Organ Donor Affiliates": "21137",
                                  "Tennessee Donor Services": "47103",
                                  },
                      "Essex": {"Center for Donation and Transplant": "36031"},
                      "Middlesex": {"LifeChoice Donor Services": "09007"},
                      "Warren" : {"LifeCenter Organ Donor Network": "39165",
                                  "Tennessee Donor Services": "47177"},
                      "Washington" : {"Intermountain Donor Services": "49053", 
                                      "Nebraska Organ Recovery System": "31177",
                                      "Alabama Organ Center" : "01129",
                                      "Kentucky Organ Donor Affiliates": "21229",
                                      "Tennessee Donor Services" : "47179"},
                      "Putnam" : {"Center for Organ Recovery and Education": "54079",
                                  "Gift of Hope Organ & Tissue Donor Network" : "17155"},
        
                      "Morgan" : {"Lifeline of Ohio": "39115"},
                      "Jackson" : {"Lifeline of Ohio": "39079", 
                                   "Midwest Transplant Network":"29095",
                                   "Alabama Organ Center" : "01071",
                                   "Tennessee Donor Services": "47087",
                                   },
                      "Rio Grande" : {"LifeLink of Puerto Rico": "72119"},
                      "Union" : {"Mid-South Transplant Foundation": "28145",
                                 "LifeLink of Georgia": "13291",
                                 "Lifeshare of the Carolinas" : "37179",
                                 "Indiana Organ Procurement Organization": "18161"},
                      "Surry" : {"Carolina Donor Services": "37171"},
                      "Burke" : {"Lifeshare of the Carolinas": "37023"},
                      "Northampton" : {"Carolina Donor Services": "37131"},
                      "Greene" : {"Carolina Donor Services": "37079",
                                  "Alabama Organ Center" : "01063",
                                  "Mid-America Transplant Services" : ["29077", "05055"],
                                  "Tennessee Donor Services" : "47059",
                                  'Gift of Hope Organ & Tissue Donor Network': "17061"
                                },
                      "Cumberland" : {"Carolina Donor Services": "37051"},
                      "Brunswick" : {"Carolina Donor Services": "37019"},
                      "Montgomery" : {"Carolina Donor Services": "37123",
                                      "Indiana Organ Procurement Organization": "18107",
                                      "Tennessee Donor Services": "47125",
                                      "Kentucky Organ Donor Affiliates": "21173",
                                      'Gift of Hope Organ & Tissue Donor Network': "17135", },
                      "Richmond" : {"Carolina Donor Services": "37153"},
                      "Saline" : {"Midwest Transplant Network":"29195"},
                      "Laurens" : {"LifeLink of Georgia": "13175"},
                      "Cherokee": {"LifeLink of Georgia": "13057"},
                      "Polk" : {"LifeLink of Georgia": "13233",
                                "Nebraska Organ Recovery System": "31143"},
                      "Jasper" : {"LifeLink of Georgia": "13159",
                                  'Gift of Hope Organ & Tissue Donor Network': "17079"},
                      "Calhoun": {"LifeLink of Georgia": "13037"},
                      "Lee" : {"LifeLink of Georgia": "13177", 
                               "Gift of Hope Organ & Tissue Donor Network": "17103"},
                      "Sumter" : {"LifeLink of Georgia": "13261"},
                      "Pickens" : {"LifeLink of Georgia": "13227"},
                      "Marion" : {"LifeLink of Georgia": "13197"},
                      "Grant" : {"LifeSource Upper Midwest Organ Procurement Organization" : "46051",
                                 "UW Health Organ and Tissue Donation" : "55043",
                                 #"Kentucky Organ Donor Affiliates": "21081",
                                 'LifeCenter Organ Donor Network': "21081"},
                      "Brown" : {"LifeSource Upper Midwest Organ Procurement Organization" : "46013",
                                 'Gift of Hope Organ & Tissue Donor Network': "17009"},
                      "Walworth" : {"LifeSource Upper Midwest Organ Procurement Organization" : "46129"},
                      "Buffalo" : {"LifeSource Upper Midwest Organ Procurement Organization" : "46017"},
                      "Rock" : {"LifeSource Upper Midwest Organ Procurement Organization" : "27133",
                                "UW Health Organ and Tissue Donation" : "55105"},
                      "Douglas" : {"Nebraska Organ Recovery System": "31055"},
                      "Webster" : {"Nebraska Organ Recovery System": "31181"},
                      "Clay" : {"Nebraska Organ Recovery System": "31035", 
                                "Southwest Transplant Alliance": "48077",
                                "Alabama Organ Center" : "01027",
                                "Tennessee Donor Services": "47027",
                                'Gift of Hope Organ & Tissue Donor Network': "17025"},
                      "Cass" : {"Nebraska Organ Recovery System": "31025", 
                                'Gift of Hope Organ & Tissue Donor Network': "17017"},
                      "Johnson" : {"Nebraska Organ Recovery System": "31097"},
                      "Sherman" : {"Nebraska Organ Recovery System": "31163"},
                      "Boone" : {"Nebraska Organ Recovery System": "31011"},
                      "Madison" : {"Nebraska Organ Recovery System": "31119",
                                   "Tennessee Donor Services" : "47113"},
                      "Wayne" : {"Nebraska Organ Recovery System": "31179",
                                 "Tennessee Donor Services": "47181",
                                 'Kentucky Organ Donor Affiliates': ["21231", "54099"],
                                 },
                      "Howard" : {"Nebraska Organ Recovery System": "31093"},
                      "Dakota" : {"Iowa Donor Network": "31043"},
                      "Fayette" : {"Alabama Organ Center" : "01057",
                                   "Indiana Organ Procurement Organization": "18041",
                                   'Gift of Hope Organ & Tissue Donor Network': "17051"},
                      "Walker" : {"Alabama Organ Center" : "01127"},
                      "Bibb" : {"Alabama Organ Center" : "01007"},
                      "Wilcox" : {"Alabama Organ Center" : "01131"},
                      "Lowndes" : {"Alabama Organ Center" : "01085"},
                      "Randolph" : {"Alabama Organ Center" : "01111"},
                      "Henry" : {"Alabama Organ Center" : "01067",
                                 "Kentucky Organ Donor Affiliates": "21103",
                                 "Tennessee Donor Services": "47079",
                                 "Gift of Hope Organ & Tissue Donor Network": "17073"},
                      "Houston" : {"Alabama Organ Center" : "01069",
                                   "Tennessee Donor Services": "47083",
                                   },
                      "Ohio" : {#"Indiana Organ Procurement Organization": "54069",
                                'LifeCenter Organ Donor Network': "18115",
                                'Kentucky Organ Donor Affiliates': "21183"},
                      "Dearborn" : {"Indiana Organ Procurement Organization": "18029"},
                      "Franklin" : {"Indiana Organ Procurement Organization": "18047",
                                    "Tennessee Donor Services": "47051"},
                      "De Kalb" : {"Indiana Organ Procurement Organization": "18033", 
                                   "LifeLink of Georgia": '13089'},
                      "DeKalb" : {"Indiana Organ Procurement Organization": "18033",
                                  "LifeLink of Georgia": '13089'},
                      "Clinton" : {"Indiana Organ Procurement Organization": "18023", 
                                   "Kentucky Organ Donor Affiliates": "21053"},
                      "Spencer" : {"Indiana Organ Procurement Organization": "18147"},
                      "Shelby" : {"Indiana Organ Procurement Organization": "18145", 
                                  "Kentucky Organ Donor Affiliates": "21211",
                                  "Gift of Hope Organ & Tissue Donor Network": "17173"},
                      "Fulton" : {"Indiana Organ Procurement Organization": "18049",
                                  "Kentucky Organ Donor Affiliates": "21075"},
                      "Marshall" : {"Indiana Organ Procurement Organization": "18099",
                                    "Gift of Hope Organ & Tissue Donor Network": "17123"},
                      "Pulaski" : {"Indiana Organ Procurement Organization": "18131" },
                      "Daviess" : {"Indiana Organ Procurement Organization": "18027" },
                      "Knox" : {"Indiana Organ Procurement Organization": "18083" },
                      "Monroe" : {"Kentucky Organ Donor Affiliates": "21171",
                                  'Lifeline of Ohio': "39111"},
                      "Marshall" : {"Gift of Hope Organ & Tissue Donor Network": "17123",
                                    "Kentucky Organ Donor Affiliates": "21157"},
                      "Logan" : {"Kentucky Organ Donor Affiliates": "21141",
                                 'Lifeline of Ohio': "39091"},
                      "Nicholas" : {"Kentucky Organ Donor Affiliates": "21181"},
                      "Jefferson" : {"Kentucky Organ Donor Affiliates": "21111"},
                      "Mississippi": {"Mid-America Transplant Services" : "29133"},
                      "Crawford" : {"Mid-America Transplant Services" : "29055",
                                    'Gift of Hope Organ & Tissue Donor Network': "17033"},
                      "St. Clair" : {"Mid-America Transplant Services" : "17163",
                                     "Midwest Transplant Network":"29185"},
                      "Hancock" : {"Tennessee Donor Services": "47067",
                                   'Gift of Hope Organ & Tissue Donor Network' : "17067"},
                      "Decatur" : {"Tennessee Donor Services": "47039"},
                      "Pike" : {"Gift of Hope Organ & Tissue Donor Network" : "17149",
                                "Indiana Organ Procurement Organization": "18125"},
                      "Grundy" : {"Gift of Hope Organ & Tissue Donor Network" : "17063"},
                      "Winnebago" : {"Gift of Hope Organ & Tissue Donor Network" : "17201"},
                      "Carroll" : {'Gift of Hope Organ & Tissue Donor Network' : "17015"},
                      "Jersey" : {"Gift of Hope Organ & Tissue Donor Network" : "17083"},
                      "Effingham" : {'Gift of Hope Organ & Tissue Donor Network' : "17049"},
                      "Lawrence" : {"Gift of Hope Organ & Tissue Donor Network": "17101",
                                    'Kentucky Organ Donor Affiliates': ["21127","17101"]},
                      "Clark" : {'Gift of Hope Organ & Tissue Donor Network': "17023"},
                      "Scott" : {'Gift of Hope Organ & Tissue Donor Network': ["17171"]},
                      #"Cabell" : {'Kentucky Organ Donor Affiliates': "54011"},
                      }


off_limits = []
for item in county_assignments:
    for org in county_assignments[item]:
        if type(county_assignments[item][org]) is list:
            for county in county_assignments[item][org]:
                off_limits.append(county)
        else:
            off_limits.append(county_assignments[item][org])

        
not_found = []
ambiguous = []
dsa_fips = {}
fips_found = []
for dsa in dsa_dict:
    
    dsa_fips_list = []
    counties = dsa_dict[dsa]["counties"]
    for county in counties:
        if county in county_dupes:
                
            if county in county_assignments:
                
                county_assignment_data = county_assignments[county]
                if dsa in county_assignment_data:
                    
                    if type(county_assignment_data[dsa]) is list:
                        
                        for county in county_assignment_data[dsa]:
                            if county not in fips_found:
                                fips_found.append(county)
                                dsa_fips_list.append(county)
                                flag = True
                        continue
                        
                    if county_assignment_data[dsa] not in fips_found:                           
                        fips_found.append(county_assignment_data[dsa])
                        dsa_fips_list.append(county_assignment_data[dsa])
                        flag = True
                        continue
                    
            
            if len(county_dupes[county]) == 1:
                dsa_fips_list.append(county_dupes[county][0])
                fips_found.append(county_dupes[county][0])
            else:
                flag = False
                
                
                
                    
                for county_fc in county_dupes[county]:
                    if off_limits[0] == county_fc:
                        pass
                    if county_fc in off_limits:
                        county_dupes[county].remove(county_fc)
                        
                   
                
                nearest_county = None
                nearest_county_distance = None
                for county_dupe in county_dupes[county]:
                    #if first digits match state and are not taken assign to this DSA
                    #otherwise, grab fips with centroid closest to state centroid
                    fips_state = county_dupe[0] + county_dupe[1]
                    
                    
                    if fips_state in dsa_dict[dsa]["state_id"] and county_dupe not in fips_found:
                        fips_found.append(county_dupe)
                        dsa_fips_list.append(county_dupe)
                        flag = True
                        break
                    else:
                        
                        for state in dsa_dict[dsa]["state"]:
                            
                            
                                
                            state_data_centroid = state_data[state]
                            county_shape = county_shape_dict[county_dupe].centroid
                            county_distance  = state_data_centroid.distance(county_shape)
                            if not nearest_county:
                                nearest_county_distance = county_distance
                                nearest_county = county_dupe
                            else:
                                if county_distance < nearest_county_distance:
                                    nearest_county_distance = county_distance
                                    nearest_county = county_dupe
                        
                if not flag:
                    if nearest_county:
                        fips_found.append(nearest_county)
                        dsa_fips_list.append(nearest_county)
                    else:
                        #print "Ambiguous: " + county
                        ambiguous.append(county)
        
        else:
            #print "Not found: " + county
            if county in manual_dict:
                dsa_fips_list.append(manual_dict[county])
                fips_found.append(manual_dict[county])
            else:
                not_found.append(county)
            
    dsa_fips[dsa] = dsa_fips_list
            
print len(ambiguous)
print len(not_found)
print not_found
# Out:
# 0
# 1
# ['De Kalb']

# %%
#Write to file, etc.

# %%
import os
import numpy as np

from matplotlib.patches import Polygon
import matplotlib.pyplot as plt
import pysal
import pylab as pl
import shapely
import shapely.geometry
from shapely.geometry import shape
from shapely.geometry import Point, LineString, Polygon, MultiPolygon 
from shapely.wkt import dumps, loads

# %%
import random
#grab a random color for coloring a figure
def get_random_color():
    r = lambda: random.randint(0,255)
    return('#%02X%02X%02X' % (r(),r(),r()))

#initialize the figure and draw the shape
def plot(shapelyGeometries, color_dict={"fill":"#AADDCC", "line":"#666666","hole_fill":"#ffffff", "hole_line":"#999999" }):
    'Plot shapelyGeometries'
    figure = pl.figure(num=None, figsize=(10, 10), dpi=180)
    axes = pl.axes()
    axes.set_aspect('equal', 'datalim')
    axes.xaxis.set_visible(False)
    axes.yaxis.set_visible(False)
    
    draw(shapelyGeometries, color_dict)
            
#Check the type and break up multipolygons        
def draw(gs, color_dict):
    'Draw shapelyGeometries'
    # Handle single and lists of geometries
    try:
        gs = iter(gs)
    except TypeError:
        gs = [gs]
    #Route polygons and multipolygons to the right place
    for g in gs:
        gType = g.geom_type
        if gType.startswith('Multi') or gType == 'GeometryCollection':
            draw(g.geoms, color_dict)
        else:
            draw_(g, color_dict)

#Break the shape into its interior and exterior rings            
def draw_(g, color_dict):

    'Draw a shapelyGeometry; thanks to Sean Gilles'
    gType = g.geom_type
    if gType == 'Point':
        pl.plot(g.x, g.y, 'k,')
    elif gType == 'LineString':
        x, y = g.xy
        pl.plot(x, y, 'b-', color=color_dict["line"])
    elif gType == 'Polygon':
        #can draw parts as multiple colors
        if not color_dict:
            color_dict={"fill":get_random_color(), 
                        "line":"#666666",
                        "hole_fill":"#FFFFFF", 
                        "hole_line":"#999999" }
    
    
        x, y = g.exterior.xy
        pl.fill(x, y, color=color_dict["fill"], aa=True) 
        pl.plot(x, y, color=color_dict["line"], aa=True, lw=1.0)
        for hole in g.interiors:
            x, y = hole.xy
            pl.fill(x, y, color=color_dict["hole_fill"], aa=True) 
            pl.plot(x, y, color=color_dict["hole_line"], aa=True, lw=1.0)

# %%
#dsa_shape_list = []
dsa_shape_dict = {}

dsa_shape = None
for dsa in dsa_fips:
    fips_codes = dsa_fips[dsa]
    dsa_shape_list = []
    for fips in fips_codes:
        
        if dsa_shape == None:
            dsa_shape = county_shape_dict[fips]
        else:
            dsa_shape = dsa_shape.union(county_shape_dict[fips])
        
        
        
        #dsa_shape_list.append(dsa_shape)
        dsa_shape_list.append(county_shape_dict[fips])
    #dsa_shape_dict[dsa] = dsa_shape_list
    dsa_shape_dict[dsa] = dsa_shape

# %%
with open('dsa_counties.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(["DSA", "FIPS"])
    for dsa in dsa_dict:
        for county in dsa_fips[dsa]:
            writer.writerow([dsa, "'"+county+"'"])

# %% [markdown]
# ### 8 Remaining Shapes that need cleanup

# %%
plot(dsa_shape_dict['Lifeline of Ohio'])

# %%
plot(dsa_shape_dict['Indiana Organ Procurement Organization'])
print dsa_dict['Indiana Organ Procurement Organization']["counties"]
print sorted(dsa_fips['Indiana Organ Procurement Organization'])
# Out:
# ['Adams', 'Allen', 'Bartholomew', 'Benton', 'Blackford', 'Boone', 'Brown', 'Carroll', 'Cass', 'Clay', 'Clinton', 'Crawford', 'Daviess', 'De Kalb', 'Decatur', 'Delaware', 'Dubois', 'Elkhart', 'Fayette', 'Fountain', 'Franklin', 'Fulton', 'Gibson', 'Grant', 'Greene', 'Hamilton', 'Hancock', 'Henderson', 'Hendricks', 'Henry', 'Howard', 'Huntington', 'Jackson', 'Jasper', 'Jay', 'Jefferson', 'Jennings', 'Johnson', 'Knox', 'Kosciusko', 'La Porte', 'Lagrange', 'Lawrence', 'Madison', 'Marion', 'Marshall', 'Martin', 'Miami', 'Monroe', 'Montgomery', 'Morgan', 'Newton', 'Noble', 'Orange', 'Owen', 'Parke', 'Perry', 'Pike', 'Posey', 'Pulaski', 'Putnam', 'Randolph', 'Ripley', 'Rush', 'Shelby', 'Spencer', 'St. Joseph', 'Starke', 'Steuben', 'Sullivan', 'Switzerland', 'Tippecanoe', 'Tipton', 'Union', 'Vanderburgh', 'Vermillion', 'Vigo', 'Wabash', 'Warren', 'Warrick', 'Washington', 'Wayne', 'Wells', 'White', 'Whitley']
# ...

# %%
plot(dsa_shape_dict['Gift of Hope Organ & Tissue Donor Network'])
print dsa_dict['Gift of Hope Organ & Tissue Donor Network']["counties"]
print sorted(dsa_fips['Gift of Hope Organ & Tissue Donor Network'])
# Out:
# ['Adams', 'Boone', 'Brown', 'Bureau', 'Calhoun', 'Carroll', 'Cass', 'Champaign', 'Christian', 'Clark', 'Clay', 'Coles', 'Cook', 'Crawford', 'Cumberland', 'De Witt', 'DeKalb', 'Douglas', 'DuPage', 'Edgar', 'Effingham', 'Fayette', 'Ford', 'Fulton', 'Greene', 'Grundy', 'Hancock', 'Henderson', 'Henry', 'Iroquois', 'Jasper', 'Jo Daviess', 'Kane', 'Kankakee', 'Kendall', 'Knox', 'La Salle', 'Lake', 'Lake', 'Lawrence', 'Lee', 'Livingston', 'Logan', 'Macon', 'Macoupin', 'Marshall', 'Mason', 'McDonough', 'McHenry', 'McLean', 'Menard', 'Mercer', 'Montgomery', 'Morgan', 'Moultrie', 'Ogle', 'Peoria', 'Piatt', 'Pike', 'Porter', 'Putnam', 'Richland', 'Rock Island', 'Sangamon', 'Schuyler', 'Scott', 'Scott', 'Shelby', 'Stark', 'Stephenson', 'Tazewell', 'Vermilion', 'Warren', 'Whiteside', 'Will', 'Winnebago', 'Woodford']
# ...

# %%
plot(dsa_shape_dict['LifeCenter Organ Donor Network'])
print dsa_dict['LifeCenter Organ Donor Network']["counties"]
print sorted(dsa_fips['LifeCenter Organ Donor Network'])
# Out:
# ['Adams', 'Boone', 'Brown', 'Butler', 'Campbell', 'Clermont', 'Clinton', 'Dearborn', 'Gallatin', 'Grant', 'Hamilton', 'Kenton', 'Ohio', 'Pendleton', 'Warren']
# [u'18029', '18115', u'21015', u'21037', u'21077', '21081', u'21117', u'21191', u'39001', u'39015', u'39017', u'39025', u'39027', u'39061', '39165']

# %%
plot(dsa_shape_dict['Midwest Transplant Network'])

# %%
plot(dsa_shape_dict['Kentucky Organ Donor Affiliates'])
print dsa_dict['Kentucky Organ Donor Affiliates']["counties"]
print sorted(dsa_fips['Kentucky Organ Donor Affiliates'])
# Out:
# ['Adair', 'Allen', 'Anderson', 'Ballard', 'Barren', 'Bath', 'Bell', 'Bourbon', 'Boyd', 'Boyle', 'Bracken', 'Breathitt', 'Breckinridge', 'Bullitt', 'Butler', 'Cabell', 'Caldwell', 'Calloway', 'Carlisle', 'Carroll', 'Carter', 'Casey', 'Christian', 'Clark', 'Clark', 'Clay', 'Clinton', 'Crittenden', 'Cumberland', 'Daviess', 'Edmonson', 'Elliott', 'Estill', 'Fayette', 'Fleming', 'Floyd', 'Floyd', 'Franklin', 'Fulton', 'Garrard', 'Graves', 'Grayson', 'Green', 'Greenup', 'Hancock', 'Hardin', 'Harlan', 'Harrison', 'Harrison', 'Hart', 'Henry', 'Hickman', 'Hopkins', 'Jackson', 'Jefferson', 'Jessamine', 'Johnson', 'Knott', 'Knox', 'Larue', 'Laurel', 'Lawrence', 'Lawrence', 'Lee', 'Leslie', 'Letcher', 'Lewis', 'Lincoln', 'Livingston', 'Logan', 'Lyon', 'Madison', 'Magoffin', 'Marion', 'Marshall', 'Martin', 'Mason', 'McCracken', 'McCreary', 'McLean', 'Meade', 'Menifee', 'Mercer', 'Metcalfe', 'Monroe', 'Montgomery', 'Morgan', 'Muhlenberg', 'Nelson', 'Nicholas', 'Ohio', 'Oldham', 'Owen', 'Owsley', '
# ...

# %% [markdown]
# ### FULLY CLEANED UP SHAPES

# %%
plot(dsa_shape_dict['Tennessee Donor Services'])
print dsa_dict['Tennessee Donor Services']["counties"]
print sorted(dsa_fips['Tennessee Donor Services'])
# Out:
# ['Anderson', 'Bedford', 'Benton', 'Bledsoe', 'Blount', 'Bradley', 'Bristol City', 'Buchanan', 'Campbell', 'Cannon', 'Carter', 'Catoosa', 'Cheatham', 'Chester', 'Claiborne', 'Clay', 'Cocke', 'Coffee', 'Crockett', 'Cumberland', 'Dade', 'Davidson', 'Decatur', 'DeKalb', 'Dickenson', 'Dickson', 'Fentress', 'Franklin', 'Gibson', 'Giles', 'Grainger', 'Greene', 'Grundy', 'Hamblen', 'Hamilton', 'Hancock', 'Hardin', 'Hawkins', 'Henry', 'Hickman', 'Houston', 'Humphreys', 'Jackson', 'Jefferson', 'Johnson', 'Knox', 'Lawrence', 'Lee', 'Lewis', 'Lincoln', 'Loudon', 'Macon', 'Madison', 'Marion', 'Marshall', 'Maury', 'McMinn', 'McNairy', 'Meigs', 'Monroe', 'Montgomery', 'Moore', 'Morgan', 'Norton City', 'Overton', 'Perry', 'Pickett', 'Polk', 'Putnam', 'Rhea', 'Roane', 'Robertson', 'Russell', 'Rutherford', 'Scott', 'Scott', 'Sequatchie', 'Sevier', 'Smith', 'Smyth', 'Stewart', 'Sullivan', 'Sumner', 'Trousdale', 'Unicoi', 'Union', 'Van Buren', 'Walker', 'Warren', 'Washington', 'Washington', 'Wayne', 'We
# ...

# %%
plot(dsa_shape_dict['LifeCenter Northwest'])
print dsa_dict['LifeCenter Northwest']["counties"]
print sorted(dsa_fips['LifeCenter Northwest'])
# Out:
# ['Adams', 'Aleutians East', 'Aleutians West', 'Anchorage', 'Asotin', 'Beaverhead', 'Benewah', 'Benton', 'Bethel', 'Big Horn', 'Blaine', 'Bonner', 'Boundary', 'Bristol Bay', 'Broadwater', 'Carbon', 'Carter', 'Cascade', 'Chelan', 'Chouteau', 'Clallam', 'Clearwater', 'Columbia', 'Custer', 'Daniels', 'Dawson', 'Deer Lodge', 'Denali', 'Dillingham', 'Douglas', 'Fairbanks North Star', 'Fallon', 'Fergus', 'Ferry', 'Flathead', 'Franklin', 'Gallatin', 'Garfield', 'Garfield', 'Glacier', 'Golden Valley', 'Granite', 'Grant', 'Grays Harbor', 'Haines', 'Hill', 'Idaho', 'Island', 'Jefferson', 'Jefferson', 'Judith Basin', 'Juneau', 'Kenai Peninsula', 'Ketchikan Gateway', 'King', 'Kitsap', 'Kittitas', 'Klickitat', 'Kodiak Island', 'Kootenai', 'Lake', 'Lake and Peninsula', 'Latah', 'Lemhi', 'Lewis', 'Lewis', 'Lewis and Clark', 'Liberty', 'Lincoln', 'Lincoln', 'Madison', 'Mason', 'Matanuska-Susitna', 'McCone', 'Meagher', 'Mineral', 'Missoula', 'Musselshell', 'Nez Perce', 'Nome', 'North Slope', 'Northwes
# ...

# %%
plot(dsa_shape_dict['Mid-America Transplant Services'])
print dsa_dict['Mid-America Transplant Services']["counties"]
print sorted(dsa_fips['Mid-America Transplant Services'])
# Out:
# ['Alexander', 'Bollinger', 'Bond', 'Butler', 'Cape Girardeau', 'Carter', 'Christian', 'Clark', 'Clay', 'Clinton', 'Craighead', 'Crawford', 'Dent', 'Dunklin', 'Edwards', 'Franklin', 'Franklin', 'Gallatin', 'Gasconade', 'Greene', 'Greene', 'Hamilton', 'Hardin', 'Howell', 'Independence', 'Iron', 'Jackson', 'Jefferson', 'Jefferson', 'Jersey', 'Johnson', 'Knox', 'Lawrence', 'Lewis', 'Lincoln', 'Madison', 'Madison', 'Maries', 'Marion', 'Marion', 'Massac', 'Mississippi', 'Monroe', 'Monroe', 'Montgomery', 'New Madrid', 'Oregon', 'Osage', 'Pemiscot', 'Perry', 'Perry', 'Phelps', 'Pike', 'Polk', 'Pope', 'Pulaski', 'Ralls', 'Randolph', 'Reynolds', 'Ripley', 'Saline', 'Scotland', 'Scott', 'Shannon', 'Shelby', 'St. Charles', 'St. Clair', 'St. Francois', 'St. Louis', 'St. Louis City', 'Ste. Genevieve', 'Stoddard', 'Taney', 'Texas', 'Union', 'Wabash', 'Warren', 'Washington', 'Washington', 'Wayne', 'Wayne', 'Webster', 'White', 'Williamson']
# ...

# %%
plot(dsa_shape_dict['LifeLink of Puerto Rico']
)
print dsa_dict['LifeLink of Puerto Rico']["counties"]
print sorted(dsa_fips['LifeLink of Puerto Rico'])
# Out:
# ['Adjuntas', 'Aguada', 'Aguadilla', 'Aguas Buenas', 'Aibonito', 'Anasco', 'Arecibo', 'Arroyo', 'Barceloneta', 'Barranquitas', "Bayamo'n", 'Cabo Rojo', 'Caguas', 'Camuy', 'Canovanas', 'Carolina', 'Catano', 'Cayey', 'Ceiba', 'Ciales', 'Cidra', 'Coamo', 'Comerio', 'Corozal', 'Culebra', 'Dorado', 'Fajardo', 'Florida', 'Guanica', 'Guayama', 'Guayanilla', 'Guaynabo', 'Gurabo', 'Hatillo', 'Hormigueros', 'Humacao', 'Jayuya', 'Juana Diaz', 'Juncos', 'Lajas', 'Lares', 'Las Marias', 'Las Piedras', 'Loiza', 'lsabela', 'Luquillo', 'Manati', 'Maricao', 'Maunabo', 'Mayaguez', 'Moca', 'Morovis', 'Naguabo', 'Naranjito', 'Orocovis', 'Patillas', 'Penuelas', 'Ponce', 'Quebradillas', 'Rincon', 'Rio Grande', 'Sabana Grande', 'Salinas', 'San German', 'San Juan', 'San Lorenzo', 'San Sebastian', 'Santa Isabel', 'St. Croix', 'St. John', 'St. Thomas', 'Toa Alta', 'Toa Baja', 'Trujillo Alto', 'Utuado', 'Vega Alta', 'Vega Baja', 'Vieques', 'Villalba', 'Yabucoa', 'Yauco']
# ...

# %%
plot(dsa_shape_dict['Lifeshare of the Carolinas'])
print dsa_dict['Lifeshare of the Carolinas']["counties"]
print sorted(dsa_fips['Lifeshare of the Carolinas'])
# Out:
# ['Anson', 'Buncombe', 'Burke', 'Cabarrus', 'Cherokee', 'Clay', 'Cleveland', 'Gaston', 'Graham', 'Haywood', 'Henderson', 'Jackson', 'Lincoln', 'Macon', 'Madison', 'Mecklenburg', 'Polk', 'Rutherford', 'Stanly', 'Swain', 'Transylvania', 'Union', 'York']
# [u'37007', u'37021', '37023', u'37025', u'37039', u'37043', u'37045', u'37071', u'37075', u'37087', u'37089', u'37099', u'37109', u'37113', u'37115', u'37119', u'37149', u'37161', u'37167', u'37173', u'37175', '37179', u'45091']

# %%
plot(dsa_shape_dict['LifeSource Upper Midwest Organ Procurement Organization'])

# %%
plot(dsa_shape_dict['LifeNet Health'])

# %%
plot(dsa_shape_dict['Washington Regional Transplant Community'])

# %%
plot(dsa_shape_dict['LifeQuest Organ Recovery Services'])

# %%
plot(dsa_shape_dict['Alabama Organ Center'])

# %%
plot(dsa_shape_dict["LifeLink of Georgia"])

# %%
plot(dsa_shape_dict['UW Health Organ and Tissue Donation'])

# %%
plot(dsa_shape_dict['LifeShare Transplant Donor Services of Oklahoma'])

# %%
plot(dsa_shape_dict['New England Organ Bank'])

# %%
plot(dsa_shape_dict['Iowa Donor Network'])

# %%
plot(dsa_shape_dict['LifeChoice Donor Services'])

# %%
plot(dsa_shape_dict['Sierra Donor Services'])

# %%
plot(dsa_shape_dict['Nebraska Organ Recovery System'])

# %%
plot(dsa_shape_dict['Texas Organ Sharing Alliance'])

# %%
plot(dsa_shape_dict['Southwest Transplant Alliance'])

# %%
plot(dsa_shape_dict['Intermountain Donor Services'])

# %%
plot(dsa_shape_dict['Mid-South Transplant Foundation'])

# %%
plot(dsa_shape_dict['Carolina Donor Services'])

# %%
plot(dsa_shape_dict['Upstate New York Transplant Services Inc'])

# %%
plot(dsa_shape_dict['Pacific Northwest Transplant Bank'])

# %%
plot(dsa_shape_dict['Center for Donation and Transplant'])

# %%
plot(dsa_shape_dict['Louisiana Organ Procurement Agency'])

# %%
plot(dsa_shape_dict['Center for Organ Recovery and Education'])

# %%
plot(dsa_shape_dict['New Mexico Donor Services'])

# %%
plot(dsa_shape_dict['LifeLink of Florida'])

# %%
plot(dsa_shape_dict['LifePoint'])

# %%
plot(dsa_shape_dict['Wisconsin Donor Network'])

# %%
plot(dsa_shape_dict['Mississippi Organ Recovery Agency'])

# %%
plot(dsa_shape_dict['The Living Legacy Foundation of Maryland'])

# %%
plot(dsa_shape_dict['California Transplant Donor Network'])

# %%
plot(dsa_shape_dict['Life Alliance Organ Recovery Agency'])

# %%
plot(dsa_shape_dict['Donor Alliance'])

# %%
plot(dsa_shape_dict['LifeGift Organ Donation Center'])

# %%
plot(dsa_shape_dict['New York Organ Donor Network'])

# %%
plot(dsa_shape_dict['Legacy of Life Hawaii'])

# %%
plot(dsa_shape_dict['Gift of Life Michigan'])

# %%
plot(dsa_shape_dict['Life Connection of Ohio'])

# %%
plot(dsa_shape_dict['TransLife'])

# %%
plot(dsa_shape_dict['Finger Lakes Donor Recovery Network'])

# %%
plot(dsa_shape_dict['LifeBanc'])

# %%
plot(dsa_shape_dict['Arkansas Regional Organ Recovery Agency'])

# %%
plot(dsa_shape_dict['Lifesharing - A Donate Life Organization'])

# %%
plot(dsa_shape_dict['Donor Network of Arizona'])

# %%
plot(dsa_shape_dict['Nevada Donor Network'])

# %%
plot(dsa_shape_dict['New Jersey Organ and Tissue Sharing Network OPO'])

# %%
plot(dsa_shape_dict['Gift of Life Donor Program'])

# %%
plot(dsa_shape_dict['OneLegacy'])
